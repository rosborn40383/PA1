# %%
##Programming Assignment 1, Richard Osborn, Version 1, CS-150-1, DUE 9/1/21
number1 = float(input('Enter floating point number: '))

number2 = int(input('Enter an integer: '))

print('The sum is', number1 + number2)

print('The difference is', number1 - number2)

print('The product is', number1 * number2)

print('The quotient is', number1 / number2)

print('The type of this result is a <class float>')
# Out:
# Enter floating point number: 66.6
# Enter an integer: 8
# The sum is 74.6
# The difference is 58.599999999999994
# The product is 532.8
# The quotient is 8.325
# The type of this result is a <class float>
